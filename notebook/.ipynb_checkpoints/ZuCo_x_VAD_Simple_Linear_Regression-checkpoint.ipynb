# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
import statsmodels.api as sm
import read_matlab_files as rf

# %%
vad_arousal = pd.read_csv(r'NRC_VAD_Lexicon/NRC-VAD-Lexicon-a-scores.csv')
vad_valence = pd.read_csv(r'NRC_VAD_Lexicon/NRC-VAD-Lexicon-v-scores.csv')
zuco_cs = pd.read_csv(r'ZuCo_words_dataset.csv')
zuco_cs = zuco_cs.drop(index=430)

# %%
zuco_ar_cs = pd.merge(zuco_cs, vad_arousal, how = 'inner', on = ['Word'])
zuco_ar_cs = zuco_ar_cs.sort_values(by=['Arousal']).reset_index(drop=True)

print(zuco_ar_cs)
# Out:
#                Word          MPS         TRT          GD         FFD  Arousal
# 0             chair  3291.975000  158.700000  117.100000   96.900000    0.082
# 1              holy  3446.666667  190.153846  106.846154   93.615385    0.112
# 2             water  3324.285714  114.285714  114.285714  114.285714    0.123
# 3            silent  3199.388889  142.666667  142.666667  107.666667    0.125
# 4            normal  3314.606061  180.272727  136.181818  114.090909    0.127
# ...             ...          ...         ...         ...         ...      ...
# 996    sharpshooter  3198.526667  204.000000  144.866667  108.133333    0.929
# 997             sex  3118.000000  150.444444  150.444444  150.444444    0.939
# 998   assassination  3375.508772  167.578947  152.684211  121.684211    0.941
# 999          battle  3268.088235  111.941176   98.294118   98.294118    0.945
# 1000         attack  3186.600000  143.400000  133.666667  123.000000    0.948
#
# [1001 rows x 6 columns]

# %%
zuco_ar_cs_MPS_AR = zuco_ar_cs.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
zuco_ar_cs_FFD_AR = zuco_ar_cs.drop(['Word', 'MPS', 'TRT', 'GD'], axis=1)
zuco_ar_cs_TRT_AR = zuco_ar_cs.drop(['Word','MPS', 'GD', 'FFD'], axis=1)
zuco_ar_cs__GD_AR = zuco_ar_cs.drop(['Word','MPS', 'TRT', 'FFD'], axis=1)

# %%
x = zuco_ar_cs_MPS_AR.iloc[:, :-1].values
y = zuco_ar_cs_MPS_AR.iloc[:, -1].values

plt.scatter(x,y, color = 'red')
x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

plt.plot(x, model.predict(x), color = 'blue')
#plt.plot(x,y, 'r.', markersize=3)
plt.title('Arousal - Mean Pupil Size Analysis')
plt.xlabel('Media Pupil Size')
plt.ylabel('Arousal')

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.9174
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.338
# Time:                        14:14:43   Log-Likelihood:                 386.20
# No. Observations:                1001   AIC:                            -768.4
# Df Residuals:                     999   BIC:                            -758.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6153      0.156      3.934      0.000       0.308       0.922
# x1         -4.594e-05    4.8e-05     -0.958      0.338      -0.000    4.82e-05
# ==============================================================================
# Omnibus:                       32.140   Durbin-Watson:                   0.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.609
# Skew:                           0.449   Prob(JB):                     3.05e-08
# Kurtosis:                       2.848   Cond. No.                     9.80e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.8e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x = zuco_ar_cs_FFD_AR.iloc[:, :-1].values
y = zuco_ar_cs_FFD_AR.iloc[:, -1].values


plt.scatter(x,y, color = 'red')

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

plt.plot(x, model.predict(x), color = 'blue')
#plt.plot(x,y, 'r.', markersize=3)
plt.title('Arousal - First Fixation Duration')

plt.xlabel('First Fixation Duration')
plt.ylabel('Arousal')
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.815
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.178
# Time:                        14:14:44   Log-Likelihood:                 386.65
# No. Observations:                1001   AIC:                            -769.3
# Df Residuals:                     999   BIC:                            -759.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4147      0.038     10.868      0.000       0.340       0.490
# x1             0.0004      0.000      1.347      0.178      -0.000       0.001
# ==============================================================================
# Omnibus:                       32.626   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               35.125
# Skew:                           0.452   Prob(JB):                     2.36e-08
# Kurtosis:                       2.837   Cond. No.                         852.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = zuco_ar_cs_TRT_AR.iloc[:, :-1].values
y = zuco_ar_cs_TRT_AR.iloc[:, -1].values

plt.scatter(x,y, color = 'red')

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

plt.plot(x, model.predict(x), color = 'blue')
#plt.plot(x,y, 'r.', markersize=3)
plt.title('Arousal - Total Time Reading')

plt.xlabel('Total Time Reading')
plt.ylabel('Arousal')

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.505
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.220
# Time:                        14:14:44   Log-Likelihood:                 386.49
# No. Observations:                1001   AIC:                            -769.0
# Df Residuals:                     999   BIC:                            -759.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4427      0.019     22.893      0.000       0.405       0.481
# x1             0.0001      0.000      1.227      0.220   -8.04e-05       0.000
# ==============================================================================
# Omnibus:                       34.286   Durbin-Watson:                   0.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.199
# Skew:                           0.467   Prob(JB):                     8.36e-09
# Kurtosis:                       2.862   Cond. No.                         658.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = zuco_ar_cs__GD_AR.iloc[:, :-1].values
y = zuco_ar_cs__GD_AR.iloc[:, -1].values

plt.scatter(x,y, color = 'red')

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

plt.plot(x, model.predict(x), color = 'blue')
#plt.plot(x,y, 'r.', markersize=3)
plt.title('Arousal - Gaze Duration')


plt.xlabel('Gaze Duration')
plt.ylabel('Arousal')

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     5.246
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):             0.0222
# Time:                        14:14:44   Log-Likelihood:                 388.36
# No. Observations:                1001   AIC:                            -772.7
# Df Residuals:                     999   BIC:                            -762.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4043      0.027     14.822      0.000       0.351       0.458
# x1             0.0005      0.000      2.290      0.022    6.71e-05       0.001
# ==============================================================================
# Omnibus:                       34.351   Durbin-Watson:                   0.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               37.198
# Skew:                           0.466   Prob(JB):                     8.37e-09
# Kurtosis:                       2.844   Cond. No.                         701.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
zuco_va_cs = pd.merge(zuco_cs, vad_valence, how = 'inner', on = ['Word'])
zuco_va_cs = zuco_va_cs.sort_values(by=['Valence']).reset_index(drop=True)
print(zuco_va_cs)
# Out:
#              Word          MPS         TRT          GD         FFD  Valence
# 0          afraid  3268.458333  121.000000   99.583333   94.500000    0.010
# 1            died  3311.213235  174.705882  126.235294  121.000000    0.021
# 2             war  3188.887931  123.431034  109.448276  101.741379    0.022
# 3         suicide  3452.428571  160.428571  160.428571  140.000000    0.030
# 4           death  3369.560606  137.113636  122.659091  108.477273    0.031
# ...           ...          ...         ...         ...         ...      ...
# 996     excellent  3301.212121  151.272727  117.636364  117.636364    0.970
# 997   prestigious  3292.333333  207.466667  171.866667  122.866667    0.979
# 998        superb  3294.916667  180.916667  149.500000  124.500000    0.980
# 999          love  3258.825000  193.050000  148.700000  131.350000    1.000
# 1000        happy  3232.790123  141.148148  111.111111  106.259259    1.000
#
# [1001 rows x 6 columns]

# %%
zuco_va_cs_FFD_VA = zuco_va_cs.drop(['Word', 'MPS', 'TRT', 'GD'], axis=1)
zuco_va_cs_TRT_VA = zuco_va_cs.drop(['Word', 'MPS', 'GD', 'FFD'], axis=1)
zuco_va_cs_GD_VA = zuco_va_cs.drop(['Word', 'MPS', 'TRT', 'FFD'], axis=1)

# %%
x = zuco_va_cs_FFD_VA.iloc[:, :-1].values
y = zuco_va_cs_FFD_VA.iloc[:, -1].values

plt.scatter(x,y, color = 'red')

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

plt.plot(x, model.predict(x), color = 'blue')
#plt.plot(x,y, 'r.', markersize=3)
plt.title('Valence - First Fixation Duration')


plt.xlabel('First Fixation Duration')
plt.ylabel('Valence')

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.815
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.178
# Time:                        14:14:44   Log-Likelihood:                 233.53
# No. Observations:                1001   AIC:                            -463.1
# Df Residuals:                     999   BIC:                            -453.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6774      0.044     15.236      0.000       0.590       0.765
# x1            -0.0005      0.000     -1.347      0.178      -0.001       0.000
# ==============================================================================
# Omnibus:                       72.666   Durbin-Watson:                   0.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.665
# Skew:                          -0.678   Prob(JB):                     9.20e-20
# Kurtosis:                       3.512   Cond. No.                         852.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = zuco_va_cs_TRT_VA.iloc[:, :-1].values
y = zuco_va_cs_TRT_VA.iloc[:, -1].values

plt.scatter(x,y, color = 'red')

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

plt.plot(x, model.predict(x), color = 'blue')
#plt.plot(x,y, 'r.', markersize=3)
plt.title('Valence - Total Time Reading')


plt.xlabel('Total Time Reading')
plt.ylabel('Valence')
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3878
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.534
# Time:                        14:14:44   Log-Likelihood:                 232.81
# No. Observations:                1001   AIC:                            -461.6
# Df Residuals:                     999   BIC:                            -451.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6316      0.023     28.011      0.000       0.587       0.676
# x1         -7.936e-05      0.000     -0.623      0.534      -0.000       0.000
# ==============================================================================
# Omnibus:                       72.550   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.556
# Skew:                          -0.677   Prob(JB):                     9.71e-20
# Kurtosis:                       3.517   Cond. No.                         658.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = zuco_va_cs_GD_VA.iloc[:, :-1].values
y = zuco_va_cs_GD_VA.iloc[:, -1].values

plt.scatter(x,y, color = 'red')

x = sm.add_constant(x)
model = sm.OLS(y,x).fit()

plt.plot(x, model.predict(x), color = 'blue')
#plt.plot(x,y, 'r.', markersize=3)
plt.title('Valence - Gaze Duration')

plt.xlabel('Gaze Duration')
plt.ylabel('Valence')

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5806
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.446
# Time:                        14:14:44   Log-Likelihood:                 232.91
# No. Observations:                1001   AIC:                            -461.8
# Df Residuals:                     999   BIC:                            -452.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6419      0.032     20.150      0.000       0.579       0.704
# x1            -0.0002      0.000     -0.762      0.446      -0.001       0.000
# ==============================================================================
# Omnibus:                       72.976   Durbin-Watson:                   0.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.159
# Skew:                          -0.679   Prob(JB):                     7.19e-20
# Kurtosis:                       3.518   Cond. No.                         701.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
