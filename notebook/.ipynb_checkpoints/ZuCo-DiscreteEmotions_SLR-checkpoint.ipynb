# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import read_matlab_files as rmf

# %% [markdown]
# ### Import the ZuCo dataset

# %%
zuco_ds = pd.read_csv('ZuCo_words_dataset.csv')
print(zuco_ds)
# Out:
#                Word          MPS         TRT          GD         FFD
# 0                he  3361.716899  131.538328  111.567944  108.419861
# 1               was  3330.888001  141.401917  110.516347  104.174746
# 2              also  3243.967949  152.076923  108.709402   99.393162
# 3               the  3315.473426  130.697804  108.107385  105.385629
# 4      unsuccessful  3442.759259  268.111111  133.500000  105.000000
# ...             ...          ...         ...         ...         ...
# 2175         oakley  3059.254902  140.352941   95.764706   91.470588
# 2176        network  3202.687500  204.750000  120.125000  120.125000
# 2177       banister  3303.098810  222.357143  148.642857  106.928571
# 2178         bureau  3208.769231  102.153846  102.153846   95.846154
# 2179  investigation  3185.541667  181.333333  139.916667  122.583333
#
# [2180 rows x 5 columns]

# %% [markdown]
# ### Get discrete emotion intensity values dataset from NRC lexicon

# %%
anger_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-anger-scores.csv')
anticipation_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-anticipation-scores.csv')
disgust_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-disgust-scores.csv')
fear_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-fear-scores.csv')
joy_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-joy-scores.csv')
sadness_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-sadness-scores.csv')
surprise_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-surprise-scores.csv')
trust_lex = pd.read_csv('NRC_Emotion_Intensity_Lexicon/NRC-Emotion-Intensity-trust-scores.csv')

# %% [markdown]
# ### Intersect each discrete emotion lexicon with the zuco used words dataset

# %%
anger_ds = pd.merge(zuco_ds, anger_lex, how ='inner', on =['Word'])
anticipation_ds = pd.merge(zuco_ds, anticipation_lex, how ='inner', on =['Word'])
disgust_ds = pd.merge(zuco_ds, disgust_lex, how ='inner', on =['Word'])
fear_ds = pd.merge(zuco_ds, fear_lex, how ='inner', on =['Word'])
joy_ds = pd.merge(zuco_ds, joy_lex, how ='inner', on =['Word'])
sadness_ds = pd.merge(zuco_ds, sadness_lex, how ='inner', on =['Word'])
surprise_ds = pd.merge(zuco_ds, surprise_lex, how ='inner', on =['Word'])
trust_ds = pd.merge(zuco_ds, trust_lex, how ='inner', on =['Word'])

# %% [markdown]
# ### Take only the interesting columns (pupil size and emotional score)

# %%
anger_ds = anger_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
anger_ds = anger_ds.sort_values(by=['AngerIntensityScore']).reset_index(drop=True)

anticipation_ds = anticipation_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
anticipation_ds = anticipation_ds.sort_values(by=['AnticipationIntensityScore']).reset_index(drop=True)

disgust_ds = disgust_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
andisgust_dsger_ds = disgust_ds.sort_values(by=['DisgustIntensityScore']).reset_index(drop=True)

fear_ds = fear_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
fear_ds = fear_ds.sort_values(by=['FearIntensityScore']).reset_index(drop=True)

joy_ds = joy_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
joy_ds = joy_ds.sort_values(by=['JoyIntensityScore']).reset_index(drop=True)

sadness_ds = sadness_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
sadness_ds = sadness_ds.sort_values(by=['SadnessIntensityScore']).reset_index(drop=True)

surprise_ds = surprise_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
surprise_ds = surprise_ds.sort_values(by=['SurpriseIntensityScore']).reset_index(drop=True)

trust_ds = trust_ds.drop(['Word','TRT', 'GD', 'FFD'], axis=1)
trust_ds = trust_ds.sort_values(by=['TrustIntensityScore']).reset_index(drop=True)

# %% [markdown]
# ### Apply simple linear regression model

# %%
import statsmodels.api as sm

# %%
X = anger_ds["MPS"]
y = anger_ds["AngerIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     AngerIntensityScore   R-squared:                       0.010
# Model:                             OLS   Adj. R-squared:                 -0.013
# Method:                  Least Squares   F-statistic:                    0.4259
# Date:                 Sat, 31 Oct 2020   Prob (F-statistic):              0.517
# Time:                         19:07:14   Log-Likelihood:                -1.5165
# No. Observations:                   45   AIC:                             7.033
# Df Residuals:                       43   BIC:                             10.65
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X = anticipation_ds["MPS"]
y = anticipation_ds["AnticipationIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                 OLS Regression Results
# ...
# Dep. Variable:     AnticipationIntensityScore   R-squared:                       0.002
# Model:                                    OLS   Adj. R-squared:                 -0.011
# Method:                         Least Squares   F-statistic:                    0.1450
# Date:                        Sat, 31 Oct 2020   Prob (F-statistic):              0.704
# Time:                                19:07:14   Log-Likelihood:                 56.561
# No. Observations:                          83   AIC:                            -109.1
# Df Residuals:                              81   BIC:                            -104.3
# Df Model:                                   1
# Covariance Type:                    nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X = disgust_ds["MPS"]
y = disgust_ds["DisgustIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     DisgustIntensityScore   R-squared:                       0.078
# Model:                               OLS   Adj. R-squared:                  0.038
# Method:                    Least Squares   F-statistic:                     1.942
# Date:                   Sat, 31 Oct 2020   Prob (F-statistic):              0.177
# Time:                           19:07:14   Log-Likelihood:                 2.2198
# No. Observations:                     25   AIC:                           -0.4396
# Df Residuals:                         23   BIC:                             1.998
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X = fear_ds["MPS"]
y = fear_ds["FearIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     FearIntensityScore   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.609
# Date:                Sat, 31 Oct 2020   Prob (F-statistic):              0.210
# Time:                        19:07:14   Log-Likelihood:               -0.92165
# No. Observations:                  55   AIC:                             5.843
# Df Residuals:                      53   BIC:                             9.858
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.7171      0.920     -0.779      0.439      -2.562       1.128
# ...

# %%
X = joy_ds["MPS"]
y = joy_ds["JoyIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      JoyIntensityScore   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.7331
# Date:                Sat, 31 Oct 2020   Prob (F-statistic):              0.394
# Time:                        19:07:15   Log-Likelihood:                 31.636
# No. Observations:                 110   AIC:                            -59.27
# Df Residuals:                     108   BIC:                            -53.87
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9779      0.620      1.576      0.118      -0.252       2.208
# ...

# %%
X = sadness_ds["MPS"]
y = sadness_ds["SadnessIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     SadnessIntensityScore   R-squared:                       0.019
# Model:                               OLS   Adj. R-squared:                 -0.001
# Method:                    Least Squares   F-statistic:                    0.9447
# Date:                   Sat, 31 Oct 2020   Prob (F-statistic):              0.336
# Time:                           19:07:15   Log-Likelihood:                -5.5347
# No. Observations:                     50   AIC:                             15.07
# Df Residuals:                         48   BIC:                             18.89
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X = surprise_ds["MPS"]
y = surprise_ds["SurpriseIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     SurpriseIntensityScore   R-squared:                       0.000
# Model:                                OLS   Adj. R-squared:                 -0.036
# Method:                     Least Squares   F-statistic:                 0.0006788
# Date:                    Sat, 31 Oct 2020   Prob (F-statistic):              0.979
# Time:                            19:07:15   Log-Likelihood:                 15.939
# No. Observations:                      30   AIC:                            -27.88
# Df Residuals:                          28   BIC:                            -25.08
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
X = trust_ds["MPS"]
y = trust_ds["TrustIntensityScore"]
plt.scatter(X, y, color='red')
X = sm.add_constant(X)
model = sm.OLS(y, X).fit()

plt.plot(X, model.predict(X), color='blue')
plt.title("Pupil Size vs Anger Intensity")
plt.xlabel("Pupil size")
plt.ylabel("Emotion intensity")
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     TrustIntensityScore   R-squared:                       0.001
# Model:                             OLS   Adj. R-squared:                 -0.005
# Method:                  Least Squares   F-statistic:                    0.2083
# Date:                 Sat, 31 Oct 2020   Prob (F-statistic):              0.649
# Time:                         19:07:15   Log-Likelihood:                 95.788
# No. Observations:                  167   AIC:                            -187.6
# Df Residuals:                      165   BIC:                            -181.3
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
